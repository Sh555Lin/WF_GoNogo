# %%
import sys
import os
import yaml


project_root = os.path.abspath("..") 
if project_root not in sys.path:
    sys.path.append(project_root)
    
from utils.preprocessing_behavior import *
from utils.plotting_behavior import *

# %%
config_path = "/home/lsh/WF_GoNogo/config/A094_config.yaml"

# %%
process_behavior_mouse_from_yaml(config_path)
# Out:
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250729/A094_20250729_220810_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250730/A094_20250730_210836_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250731/A094_20250731_175837_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250801/A094_20250801_174655_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250804/A094_20250804_171415_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250805/A094_20250805_170732_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250806/A094_20250806_195618_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250807/A094_20250807_195428_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250808/A094_20250808_175628_Data_.mat
# Processing /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/20250811/A094_20250811_170040_Data_.mat

# %%
run_behavior_from_config(config_path)
# Out:
# Session: 20250729_220810 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250730_210836 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250731_175837 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250801_174655 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250804_171415 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250805_170732 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250806_195618 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250807_195428 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# Session: 20250808_175628 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...empty dataset written
# CR_licks...empty dataset written
# FA_licks...done
#
# Writing data on date: 20250811
# Session: 20250811_170040 is adding...
# trial_results...done
# Hit_licks...done
# Miss_licks...done
# CR_licks...done
# FA_licks...done
# 训练记录写入成功！

# %%
import yaml

with open(config_path, 'r') as f:
    cfg = yaml.safe_load(f)

plot_metric_across_days(cfg, metric='dprime')
plot_metric_across_days(cfg, metric='accuracy')
plot_metric_across_days(cfg, metric='hit_fa')
# Out:
# [⚠] training_history 不存在，跳过历史标注
# [⚠️] 跳过 20250729: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250730: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250731: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250801: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250804: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250805: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250806: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250807: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250808: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250811: cannot access local variable 'history_dict' where it is not associated with a value
# [✔] 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/figures/A094_dprime_curve_20250812.png
# [⚠] training_history 不存在，跳过历史标注
# [⚠️] 跳过 20250729: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250730: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250731: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250801: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250804: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250805: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250806: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250807: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250808: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250811: cannot access local variable 'history_dict' where it is not associated with a value
# [✔] 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/figures/A094_accuracy_curve_20250812.png
# [⚠] training_history 不存在，跳过历史标注
# [⚠️] 跳过 20250729: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250730: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250731: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250801: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250804: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250805: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250806: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250807: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250808: cannot access local variable 'history_dict' where it is not associated with a value
# [⚠️] 跳过 20250811: cannot access local variable 'history_dict' where it is not associated with a value
# [✔] 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A094/figures/A094_hit_fa_curve_20250812.png

# %%
plot_go_nogo_lick_raster_by_yaml_config(cfg)
# Out:
# 20250729 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250729_20250811.png
# 20250730 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250730_20250811.png
# 20250731 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250731_20250811.png
# 20250801 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250801_20250811.png
# 20250804 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250804_20250811.png
# 20250805 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250805_20250811.png
# 20250806 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250806_20250811.png
# 20250807 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250807_20250811.png
# 20250808 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_raster_20250808_20250811.png

# %%
plot_hit_fa_scatter_from_yaml(cfg)
# Out:
# [⚠️] HDF5 中无 training_history，跳过历史事件绘制
# [✔] 图像已保存至: /home/lsh/Data_attention/Transfer learning/DATA_linshu/A092/figures/A092_training_results_20250811.png
